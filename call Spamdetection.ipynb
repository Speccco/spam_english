# %%
import nbimporter
import Spamdetection  # Replace with your actual notebook name (without .ipynb)

# %%
# %run Spamdetection.ipynb

# %%
exec(open("Spamdetection.ipynb").read())

# %%
jupyter nbconvert --to script Spam.ipynb

# %%
import Spamdetection  # Ensure my_notebook.py is in the same directory

# %%
import importlib.util

notebook_path = "my_notebook.ipynb"
module_name = "my_notebook"

spec = importlib.util.spec_from_file_location(module_name, notebook_path)
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)
